# %% [markdown]
# # TestFunctions.jl Gallery

# %%
using TestFunctions
using PGFPlots

# %% [markdown]
# ### Ackley

# %%
Plots.Contour(ackley, (-30.0,30.0), (-30.0,30.0))
# Out:
# PGFPlots.Plots.Contour([-29.9256 -28.391 … 28.391 29.9256; -27.5593 -26.026 … 30.7051 32.2384; … ; -27.5593 -26.026 … 30.7051 32.2384; -29.9256 -28.391 … 28.391 29.9256], -30.0:1.5384615384615385:30.0, -30.0:1.5384615384615385:30.0, nothing, nothing, nothing, nothing, nothing)

# %% [markdown]
# ### Booth

# %%
Plots.Contour(booth, (-10.0,10.0), (-10.0,10.0), levels=logspace(0.0,3.0,10))
# Out:
# PGFPlots.Plots.Contour([2594.0 2483.52 … 244.546 234.0; 2485.57 2377.2 … 216.064 207.623; … ; 322.494 291.962 … 1011.04 1080.44; 314.0 285.571 … 1082.49 1154.0], -10.0:0.5128205128205128:10.0, -10.0:0.5128205128205128:10.0, nothing, nothing, nothing, [1.0, 2.15443, 4.64159, 10.0, 21.5443, 46.4159, 100.0, 215.443, 464.159, 1000.0], nothing)

# %% [markdown]
# ### Branin

# %%
Plots.Contour(branin, (-7.0,20.0), (-5.0,25.0), levels=logspace(0.0,3.0,10))
# Out:
# PGFPlots.Plots.Contour([827.83 784.621 … 17.8165 19.5772; 704.932 665.249 … 28.9133 34.2003; … ; 826.829 783.683 … 19.2545 21.0795; 965.198 918.339 … 16.5171 14.6288], -7.0:0.6923076923076923:20.0, -5.0:0.7692307692307693:25.0, nothing, nothing, nothing, [1.0, 2.15443, 4.64159, 10.0, 21.5443, 46.4159, 100.0, 215.443, 464.159, 1000.0], nothing)

# %% [markdown]
# ### Flower

# %%
Plots.Contour(flower, (-3.0,3.0), (-3.0,3.0), levels=logspace(0.0,2.0,15))
# Out:
# PGFPlots.Plots.Contour([4.24264 4.24033 … 4.03024 4.24264; 4.03024 4.02507 … 4.02507 4.24033; … ; 4.24033 4.02507 … 4.02507 4.03024; 4.24264 4.03024 … 4.24033 4.24264], -3.0:0.15384615384615385:3.0, -3.0:0.15384615384615385:3.0, nothing, nothing, nothing, [1.0, 1.3895, 1.9307, 2.6827, 3.72759, 5.17947, 7.19686, 10.0, 13.895, 19.307, 26.827, 37.2759, 51.7947, 71.9686, 100.0], nothing)

# %% [markdown]
# ### Michalewicz

# %%
Plots.Contour(michalewicz, (0.0,4.0), (0.0,4.0))
# Out:
# PGFPlots.Plots.Contour([-0.0 -3.36966e-45 … 3.54154e-13 0.00044954; -3.21392e-51 -3.36967e-45 … 3.54154e-13 0.00044954; … ; 0.589753 0.589753 … 0.589753 0.590203; 0.171469 0.171469 … 0.171469 0.171918], 0.0:0.10256410256410256:4.0, 0.0:0.10256410256410256:4.0, nothing, nothing, nothing, nothing, nothing)

# %% [markdown]
# ### Rosenbrock

# %%
Plots.Contour(rosenbrock, (-2.0,2.0), (-2.0,2.0), levels=logspace(0.0,3.0,10))
# Out:
# PGFPlots.Plots.Contour([189.0 182.899 … 31.1039 29.0; 165.21 159.519 … 22.8932 21.1993; … ; 157.62 151.929 … 15.3035 13.6096; 181.0 174.899 … 23.1039 21.0], -2.0:0.10256410256410256:2.0, -2.0:0.10256410256410256:2.0, nothing, nothing, nothing, [1.0, 2.15443, 4.64159, 10.0, 21.5443, 46.4159, 100.0, 215.443, 464.159, 1000.0], nothing)

# %% [markdown]
# ### Wheeler

# %%
Plots.Contour(wheeler, (0,2.5), (0.0,2.5))
# Out:
# PGFPlots.Plots.Contour([-0.011109 -0.0134094 … -0.0438972 -0.0387742; -0.011109 -0.0135755 … -0.0684368 -0.0611202; … ; -0.011109 -0.0209055 … -1.20996e-9 -2.61197e-10; -0.011109 -0.0211373 … -2.95708e-10 -5.84704e-11], 0.0:0.0641025641025641:2.5, 0.0:0.0641025641025641:2.5, nothing, nothing, nothing, nothing, nothing)

# %% [markdown]
# ### Circle

# %%
Plots.Contour(x->circle(x)[1], (-π,π), (-2.0,6.0))
# Out:
# PGFPlots.Plots.Contour([1.1 1.07483 … 1.66758 1.66216; 1.09871 1.07386 … 1.65893 1.65359; … ; 1.09871 1.07386 … 1.65893 1.65359; 1.1 1.07483 … 1.66758 1.66216], -3.141592653589793:0.16110731556870733:3.141592653589793, -2.0:0.20512820512820512:6.0, nothing, nothing, nothing, nothing, nothing)

# %%
Plots.Contour(x->circle(x)[2], (-π,π), (-2.0,6.0))
# Out:
# PGFPlots.Plots.Contour([1.0 1.0 … 1.0 1.0; 1.01604 1.012 … 1.10709 1.10622; … ; 0.983959 0.987996 … 0.892913 0.893782; 1.0 1.0 … 1.0 1.0], -3.141592653589793:0.16110731556870733:3.141592653589793, -2.0:0.20512820512820512:6.0, nothing, nothing, nothing, nothing, nothing)
